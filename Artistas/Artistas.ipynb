# %% [markdown]
# # Centralidade & Disruptividade
# ---
# O intuito deste jupyter notebook é a organização do código em Python para demonstrações e vizualizações.
# A verificação é observada apartir das funções criadas que estão sendo importadas do graphutils - somente isso no momento.
# Para mais informações contatem os membros do GitHub.
#
# As bibliotecas usadas são:
# > Networkx
# >
# > Pandas
# >
# > Numpy

# %%
from grafoutils import *
from plotutils import *
from simulation import *
from centralidade import *

# %% [markdown]
# ### Criando o grafo
# Para criar o grafo, é útilizado a data da rede de pessoas - neste caso os artistas - e utiliza da função get_grafo(), a qual recebe a data_desejada - data de conexões - para criar a rede desejada. No caso a seguir é o grafo pertecente as conexões entre artistas musicais (que será referênciado como somente artistas).
#
# *OBS*: Como não foi passado seleções de nos especificos, é criado toda a rede social. Caso fosse passado uma lista de nos, o código procuraria somente por ela.

# %%
data_desejada = get_data_gz('artists.json')

# %%
grafo = get_grafo(data_desejada)

# %%
#grafo.edges() para verificar as conexões

# %% [markdown]
# ### Criando o DataFrame
# O data frame é criado apartir do resultado de disruptividade - anteriormente calculado - ou nomeclaturas dos indivíduos, tal qual gênero, decada e mais. Eles serão importantes para a observação de padrões na rede social. Para isso usa a função get_df, de assinatura *get_df(nome_arquivo,extensão)*. No caso a seguir, será o de artistas:

# %%
df = get_df('disrupt','csv')

# %%
df
# Out:
#              label     ni    nj      nk  disruption             name  \
# 0     mn0003013627    2.0   0.0    75.0    0.025974         Daughter
# 1     mn0000206668    1.0   0.0   304.0    0.003279          Des'ree
# 2     mn0000622805  236.0  56.0  1566.0    0.096878    Stevie Wonder
# 3     mn0000576718    4.0   4.0  1986.0    0.000000             Seal
# 4     mn0000302106    5.0   3.0   612.0    0.003226  Lisa Stansfield
# ...            ...    ...   ...     ...         ...              ...
# 7428  mn0000669855    0.0   1.0   763.0   -0.001309      Heidi Berry
# 7429  mn0000605992    0.0   1.0   201.0   -0.004950   Muggsy Spanier
# 7430  mn0000410010    1.0   0.0    90.0    0.010989        Nicolette
# 7431  mn0000100312    1.0   0.0   249.0    0.004000             Klee
# 7432  mn0000819405    0.0   1.0    52.0   -0.018868   Leroy Vinnegar
#
#       confidence
# 0         0.6747
# 1         0.5910
# 2         1.0000
# 3         0.4939
# 4         0.6572
# ...          ...
# 7428      0.5858
# 7429      0.5908
# 7430      0.5824
# 7431      0.5887
# 7432      0.5780
#
# [7433 rows x 7 columns]

# %%
df_nome_id = df.get(['label','name']).set_index('label')
df_nome_id.to_csv('../data/Artistas/artistas_nomes_label.csv',index=True)

# %% [markdown]
# ### Utilizando das funções para organizar melhores grafos
# Para fazer o uso de verificações viáveis nos grafo, é necessário selecionar partições do grafo de maior conexão para o computador percorrer cada parte em tempo viável e gerar vizualizações, principalmente este último. Para selecionar de maneira rápida, utilizamos do poder dos dataframe para afzer consultas e organizar os dados, afim de selecionar os nos interresantes por algum motivo. Em cada caso, há uma tabela de disruptividade e uma de nomeclatura para cada caso, para os artistas, há o get_artistas_df():

# %%
disruption_genre = get_artistas_df()

# %%
disruption_genre
# Out:
#                                 name  earliest_decade           genre    ni  \
# label
# mn0000249175              Les Baxter           1940.0  Easy Listening   7.0
# mn0000150502             Henry Brant           1950.0       Classical   1.0
# mn0000942680             Café Tacuba           1980.0           Latin   4.0
# mn0000809357              Jan Hammer           1960.0            Jazz   8.0
# mn0000255704                  Pegboy           1990.0        Pop/Rock   4.0
# ...                              ...              ...             ...   ...
# mn0000633079  Strawberry Alarm Clock           1960.0        Pop/Rock   4.0
# mn0000359062                   KMFDM           1980.0        Pop/Rock  15.0
# mn0000769109               Kid Koala           1990.0      Electronic   1.0
# mn0000527024         Bruce Dickinson           1970.0        Pop/Rock   6.0
# mn0000750203           Slim Gaillard           1930.0           Vocal   5.0
#
#                nj      nk  disruption  confidence
# label
# mn0000249175  4.0   349.0    0.008333      0.7022
# mn0000150502  1.0    41.0    0.000000      0.5050
# mn0000942680  6.0  1201.0   -0.001652      0.6520
# mn0000809357  1.0  2411.0    0.002893      0.9062
# mn0000255704  1.0   777.0    0.003836      0.7319
# ...           ...     ...         ...         ...
# mn0000633079  1.0  2256.0    0.001327      0.7321
# mn0000359062  4.0   978.0    0.011033      0.9627
# mn0000769109  1.0   613.0    0.000000      0.5081
# mn0000527024  2.0   406.0    0.009662      0.7813
# mn0000750203  8.0   413.0   -0.007042      0.6944
#
# [3917 rows x 8 columns]

# %% [markdown]
# Em seguida, utiliza-se a função get_grafo_parametros - com assinatura *get_grafo_parametro(data_desejada, dataframe_desejado, parametro_primeiro, valor_primeiro, parametro_epoca, valor_chao_epoca, valor_teto_epoca)* - para pegar os nos desejados e criar um subgrafo da conexão total com eles.

# %%
grafo_genre = get_grafo_parametros(data_desejada,disruption_genre,'genre','Jazz','earliest_decade',1980)

# %% [markdown]
# Abaixo. temos a função de vizualização simples, que utiliza de um grafo qualquer para criar a vizualização da forma de assinatura:
# *gera_grafico(grafo,df,numero_disrupcao,cor_principais,cor_secundarios,tamanho_texto,largura,altura)*

# %%
plot_teste = gera_grafico(grafo_genre,disruption_genre,0.2,largura=20,altura=20)
plot_teste

# %% [markdown]
# ### Resiliência dos Grafos
# Para testar a resiliência dos grafos e sua relação com a disrupção e centralidade, vai ser verificado por código utilizando de métodos randomizados para seleção de nós iniciais, finais e o nó intermédiário/central, para analisar as conexões.

# %%
np.random.seed(42)
total = grafo_simulation_short_path()
total
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
lista_histograma(total)

# %% [markdown]
# ### Centralidade
# Existem diversas medidas de centralidades que podem ser tiradas de um grafo. Para Medir as centralidades em diferentes métodos e apresentar o resultado, foi feita uma função para usar os métodos como variáveis e retornar uma lista com as medidas para serem colocadas em um gráfico. A função é chamada de *centralidade()*, com assinatura *centralidade(metodo,genero)*.

# %%
resultado_grau = centralidade()
resultado_in = centralidade(nx.in_degree_centrality)
resultado_out = centralidade(nx.out_degree_centrality)
resultado_between = centralidade(nx.betweenness_centrality)

# %%
resultados = [resultado_grau,resultado_in,resultado_out,resultado_between]
for resultado in resultados:
    lista_histograma(list(resultado.values()),title='Resultados Centralidade',xlabel='Resultado')

# %%
resultados = [resultado_grau,resultado_in,resultado_out,resultado_between]
for resultado in resultados:
    resultado_disrupcao = [disruption_genre.loc[r].get('disruption')
                      if r in disruption_genre.index 
                      else None
                      for r in resultado]
    
    resultado_valor = [ resultado[r]
                      if r in disruption_genre.index 
                      else None
                      for r in resultado.keys()]
    
    listas_dispersao(resultado_disrupcao,resultado_valor,xlabel='Disrupção',ylabel='Valor Centralidade')

# %% [markdown]
# ### Exportação do Grafo

# %%
nx.write_edgelist(grafo,'../data/Artistas/grafo_artistas.csv', data=False)
